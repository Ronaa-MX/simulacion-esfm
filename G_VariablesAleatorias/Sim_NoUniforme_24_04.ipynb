# %% [markdown]
# <a href="https://colab.research.google.com/github/Ronaa-MX/simulacion-esfm/blob/simulacion-I/Sim_NoUniforme_24_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Caso de simulación con distribución no uniforme
#
# Generaremos una distribución no uniforme, en base a la distribución uniforme por el método de transformada inversa. Para el caso de la exponencial.

# %%
# Debotamos la variable aleatoria a trabajar
