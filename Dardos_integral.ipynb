# %%
#Librerías
import numpy as np
import matplotlib.pyplot as plt

# %%
def integrate(x1,x2,func=test_function,n=100000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    print(x1,x2,y1,y2)
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    for i in range(n):
        x=np.random.uniform(x1,x2,1)
        xs.append(x)
        y=np.random.uniform(y1,y2,1)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
return(np.mean(check)*area,xs,ys,check)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_39989/604599376.py in <cell line: 0>()
# ----> 1 def integrate(x1,x2,func=test_function,n=100000):
#       2     X=np.linspace(x1,x2,1000)
#       3     y1=0
#       4     y2=max((func(X)))
#       5     print(x1,x2,y1,y2)
#
# NameError: name 'test_function' is not defined
